# %% [markdown]
# <a href="https://colab.research.google.com/github/MMR1318/Maheshreddy_INFO5731_Fall2024/blob/main/Group5_final_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ACM Pre processing

# %%
import pandas as pd
import re

# Load the scraped data
data = pd.read_excel('acm_library_abstract_results.xlsx')

data.head()
# Out:
#                                                title  published_year  \
# 0  Promoting Ethical Use of Generative AI in Educ...            2024
# 1  The Roles and Functions of Foreign Language Te...            2024
# 2  Research on Innovative Applications and Impact...            2024
# 3  L@S '24: Proceedings of the Eleventh ACM Confe...            2024
# 4  Understanding the Adoption of ChatGPT in Highe...            2024
#
#                                                  url  \
# 0  https://dl-acm-org.libproxy.library.unt.edu/do...
# 1  https://dl-acm-org.libproxy.library.unt.edu/do...
# 2  https://dl-acm-org.libproxy.library.unt.edu/do...
# 3  https://dl-acm-org.libproxy.library.unt.edu/do...
# 4  https://dl-acm-org.libproxy.library.unt.edu/do...
#
#                                              authors  page_num  \
# 0              ['Xuefei (Nancy) Deng', 'K.D. Joshi']       NaN
# 1                    ['Yushuang Zhang', 'Miao Miao']       NaN
# 2     ['Chia-Ling Ho', 'Xin-Ying Liu', 'Yu-Wei Qiu']       NaN
# 3                    ['David Joyner', 'Min Kyu Kim']       NaN
# 4  ['Ann-Kathrin Kubullek', 'Nadire Kumaç', 'Ayse...       NaN
#
#   published_month                                           abstract
# 0            July  Abstract\nGenerative artificial intelligence (...
# 1         October  Abstract\nWith the rapid development of Genera...
# 2            July  Abstract\nGenerative Artificial Intelligence (...
# 3            July                                                NaN
# 4       September  Abstract\nSince ChatGPT’s introduction, genera...

# %%
data.shape
# Out:
# (2147, 7)

# %%
df=data.drop(['page_num','published_month'], axis=1)

# %%
# Handling missing values: Dropping rows with missing titles or abstracts
df = df.dropna(subset=['title', 'abstract'])

# %%
# Removing duplicates
df = df.drop_duplicates()

# %%
# Text cleaning function
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower()

# %%
df['title'] = df['title'].apply(clean_text)
df['abstract'] = df['abstract'].apply(clean_text)

# %%
df.shape
# Out:
# (1620, 5)

# %%
# Save cleaned data
df.to_excel('cleaned_acm.xlsx', index=False)

# %% [markdown]
# Science Direct pre processing

# %%
data = pd.read_excel('science_direct_results.xlsx')

data.head()
# Out:
#                                                title  \
# 0  Will generative AI replace teachers in higher ...
# 1  Navigating challenges and opportunities: Nursi...
# 2  Integrating generative AI in management educat...
# 3  Exploring the integration of IoT and Generativ...
# 4  Why students use or not use generative AI: Stu...
#
#                                                  url  \
# 0  https://www-sciencedirect-com.libproxy.library...
# 1  https://www-sciencedirect-com.libproxy.library...
# 2  https://www-sciencedirect-com.libproxy.library...
# 3  https://www-sciencedirect-com.libproxy.library...
# 4  https://www-sciencedirect-com.libproxy.library...
#
#                              doi  \
# 0  10.1016/j.stueduc.2024.101395
# 1     10.1016/j.nepr.2024.104062
# 2     10.1016/j.ijme.2024.101017
# 3     10.1016/j.jocs.2024.102397
# 4      10.1016/j.dte.2024.100019
#
#                                              authors  \
# 0        ['Cecilia Ka Yuk Chan', 'Louisa H. Y. Tsi']
# 1  ['Anthony Summers', 'May El Haddad', 'Florin O...
# 2  ['Pragya Gupta', 'Renuka Mahajan', 'Pooja. S. ...
# 3       ['Wanjin Dong', 'Daohua Pan', 'Soonbae Kim']
# 4                                        ['Yun Dai']
#
#                      published_date  \
# 0                     December 2024
# 1                       August 2024
# 2                     November 2024
# 3                      October 2024
# 4  Available online 5 November 2024
#
#                                             abstract  page_num
# 0  This paper evaluates the potential of generati...         1
# 1  This paper evaluates the potential of generati...         1
# 2  This paper evaluates the potential of generati...         1
# 3  This paper evaluates the potential of generati...         1
# 4  This paper evaluates the potential of generati...         1

# %%
data.shape
# Out:
# (2038, 7)

# %%
df=data.drop(['page_num','doi'], axis=1)

# %%
# Handling missing values: Dropping rows with missing titles or abstracts
df = df.dropna(subset=['title', 'abstract'])

# %%
# Removing duplicates
df = df.drop_duplicates()

# %%
# Function to extract year from the 'published_date' column
def extract_year(date_str):
    match = re.search(r'\b(20\d{2})\b', str(date_str))  # Look for years in the format 20XX
    return int(match.group(1)) if match else None

df['year'] = df['published_date'].apply(extract_year)

df = df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)

# %%
df=df.drop(['published_date'], axis=1)

# %%
# Text cleaning function
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower()

# %%
df['title'] = df['title'].apply(clean_text)
df['abstract'] = df['abstract'].apply(clean_text)

# %%
df.shape
# Out:
# (2038, 5)

# %%
# Save cleaned data
df.to_excel('cleaned_Science_direct.xlsx', index=False)

# %% [markdown]
# Scopus Pre processing

# %%
# Load the scraped data
data = pd.read_excel('scopus_results.xlsx')

data.head()
# Out:
#                                                title  \
# 0  Analyzing Flipped Classroom Themes Trends in C...
# 1  LAMB: An open-source software framework to cre...
# 2  Enhancing digital literacy in foreign language...
# 3  Reducing interpretative ambiguity in an educat...
# 4  Development and techniques in learner model in...
#
#                                                  url  \
# 0  https://www-scopus-com.libproxy.library.unt.ed...
# 1  https://www-scopus-com.libproxy.library.unt.ed...
# 2  https://www-scopus-com.libproxy.library.unt.ed...
# 3  https://www-scopus-com.libproxy.library.unt.ed...
# 4  https://www-scopus-com.libproxy.library.unt.ed...
#
#                                              authors  journal  \
# 0                       ['Keong, T.C.', 'Jimei, G.']      NaN
# 1  ['Alier, M.', 'Pereira, J.', 'García-Peñalvo, ...      NaN
# 2                                      ['Jiang, B.']      NaN
# 3  ['Garcia-Varela, F.', 'Bekerman, Z.', 'Nussbau...      NaN
# 4         ['Wang, X.', 'Yukiko, M.', 'Chang, H.-H.']      NaN
#
#   publication_details  published_year  \
# 0    46(1), pp. 15–27            2025
# 1          92, 103940            2025
# 2         154, 104845            2025
# 3         225, 105182            2025
# 4         225, 105184            2025
#
#                                             abstract  page_num
# 0  Flipped classroom (FC) overcomes many drawback...         1
# 1  This paper presents LAMB (Learning Assistant M...         1
# 2  For foreign language teachers to successfully ...         1
# 3  The study posits that both concrete and abstra...         1
# 4  Adaptive e-learning systems (AeLS), which emer...         1

# %%
data.shape
# Out:
# (20452, 8)

# %%
df=data.drop(['page_num','publication_details','journal'], axis=1)

# %%
# Handling missing values: Dropping rows with missing titles or abstracts
df = df.dropna(subset=['title', 'abstract'])

# %%
# Removing duplicates
df = df.drop_duplicates()

# %%
# Text cleaning function
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower()

# %%
df['title'] = df['title'].apply(clean_text)
df['abstract'] = df['abstract'].apply(clean_text)

# %%
df.shape
# Out:
# (1901, 5)

# %%
# Save cleaned data
df.to_excel('cleaned_Scopus.xlsx', index=False)

# %% [markdown]
# IEEE preprocessing

# %%
import pandas as pd
# Load the scraped data
data = pd.read_excel('output_data.xlsx')

data.head()
# Out:
#                                               title   published_year  \
# 0  Application Research of Generative Artificial ...            2024
# 1  A Comprehensive Review on Generative AI for Ed...            2024
# 2  Application of Generative Artificial Intellige...            2024
# 3  The Generative AI Landscape in Education: Mapp...            2024
# 4              Generative AI in Higher Art Education            2024
#
#                                                  url  \
# 0  https://ieeexplore-ieee-org.libproxy.library.u...
# 1  https://ieeexplore-ieee-org.libproxy.library.u...
# 2  https://ieeexplore-ieee-org.libproxy.library.u...
# 3  https://ieeexplore-ieee-org.libproxy.library.u...
# 4  https://ieeexplore-ieee-org.libproxy.library.u...
#
#                                              authors  page_num  \
# 0  ['Jing Ning', 'Yi Gao', 'Mingxin Luo', '', '',...       NaN
# 1  ['Uday Mittal', 'Siva Sai', 'Vinay Chamola', '...       NaN
# 2  ['Ying Li', 'Wei Ji', 'Jiaqi Liu', 'Wenqing Li...       NaN
# 3  ['Zishan Ahmed', 'Shakib Sadat Shanto', 'Most....       NaN
# 4   ['Xi Chen', 'Yuebin Liao', 'Wei Yu', '', '', '']       NaN
#
#                                             abstract  \
# 0  Abstract:\nThe education mode of art design ed...
# 1  Abstract:\nArtificial Intelligence (AI) has im...
# 2  Abstract:\nIn today's rapidly evolving educati...
# 3  Abstract:\nGenerative AI (GAI) technologies li...
# 4  Abstract:\nThis research delves into the persp...
#
#                                  doi        publisher    published_date  \
# 0  DOI: 10.1109/IECA62822.2024.00038  Publisher: IEEE    12 August 2024
# 1   DOI: 10.1109/ACCESS.2024.3468368  Publisher: IEEE               NaN
# 2  DOI: 10.1109/IIST62526.2024.00099  Publisher: IEEE  04 November 2024
# 3   DOI: 10.1109/ACCESS.2024.3461874  Publisher: IEEE               NaN
# 4  DOI: 10.1109/CSTE62025.2024.00032  Publisher: IEEE      18 July 2024
#
#       conference_date Unnamed: 10
# 0  26-28 January 2024         NaN
# 1                 NaN         NaN
# 2    04-05 March 2024         NaN
# 3                 NaN         NaN
# 4    19-21 April 2024         NaN

# %%
data.shape
# Out:
# (11306, 11)

# %%
df=data.drop(['page_num','published_date','doi','publisher','published_date','conference_date','Unnamed: 10'], axis=1)

# %%
print(df.columns)
# Out:
# Index(['title ', 'published_year', 'url', 'authors', 'abstract'], dtype='object')

# %%
# Handling missing values: Dropping rows with missing titles or abstracts
df = df.dropna(subset=['title ', 'abstract'])

# %%
# Removing duplicates
df = df.drop_duplicates()

# %%
# Text cleaning function
def clean_text(text):
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower()

# %%
import re
df['title '] = df['title '].apply(clean_text)
df['abstract'] = df['abstract'].apply(clean_text)

# %%
df.shape
# Out:
# (8577, 5)

# %%
# Save cleaned data
df.to_excel('cleaned_IEEE.xlsx', index=False)

# %% [markdown]
# Merging

# %%
ieee = pd.read_excel('cleaned_IEEE.xlsx')

sd = pd.read_excel('cleaned_Science_direct.xlsx')

s = pd.read_excel('cleaned_Scopus.xlsx')

acm = pd.read_excel('cleaned_acm.xlsx')

# %%
ieee = ieee.rename(columns={'title ': 'title'})

# %%
ieee.columns
# Out:
# Index(['title', 'published_year', 'url', 'authors', 'abstract'], dtype='object')

# %%
sd.columns
# Out:
# Index(['title', 'url', 'authors', 'abstract', 'year'], dtype='object')

# %%
sd = sd.rename(columns={'year': 'published_year'})

# %%
sd.columns
# Out:
# Index(['title', 'url', 'authors', 'abstract', 'published_year'], dtype='object')

# %%
s.columns
# Out:
# Index(['title', 'url', 'authors', 'published_year', 'abstract'], dtype='object')

# %%
acm.columns
# Out:
# Index(['title', 'published_year', 'url', 'authors', 'abstract'], dtype='object')

# %%
ieee = ieee[ieee.columns]
sd = sd[ieee.columns]
s = s[ieee.columns]
acm = acm[ieee.columns]

# %%
merged_df = pd.concat([ieee, sd, s, acm], ignore_index=True)

# Save the merged DataFrame
merged_df.to_excel('merged_file.xlsx', index=False)

# %%
merged_df.shape
# Out:
# (14136, 5)

# %%
# Removing duplicates
data = merged_df.drop_duplicates()

# %%
data.shape
# Out:
# (14135, 5)

# %% [markdown]
# "EDA"

# %%
import pandas as pd
import re
data = pd.read_excel('/content/merged_file.xlsx')

data.head()
# Out:
#                                                title  published_year  \
# 0  application research of generative artificial ...            2024
# 1  a comprehensive review on generative ai for ed...            2024
# 2  application of generative artificial intellige...            2024
# 3  the generative ai landscape in education mappi...            2024
# 4              generative ai in higher art education            2024
#
#                                                  url  \
# 0  https://ieeexplore-ieee-org.libproxy.library.u...
# 1  https://ieeexplore-ieee-org.libproxy.library.u...
# 2  https://ieeexplore-ieee-org.libproxy.library.u...
# 3  https://ieeexplore-ieee-org.libproxy.library.u...
# 4  https://ieeexplore-ieee-org.libproxy.library.u...
#
#                                              authors  \
# 0  ['Jing Ning', 'Yi Gao', 'Mingxin Luo', '', '',...
# 1  ['Uday Mittal', 'Siva Sai', 'Vinay Chamola', '...
# 2  ['Ying Li', 'Wei Ji', 'Jiaqi Liu', 'Wenqing Li...
# 3  ['Zishan Ahmed', 'Shakib Sadat Shanto', 'Most....
# 4   ['Xi Chen', 'Yuebin Liao', 'Wei Yu', '', '', '']
#
#                                             abstract
# 0  abstract the education mode of art design educ...
# 1  abstract artificial intelligence ai has immens...
# 2  abstract in todays rapidly evolving education ...
# 3  abstract generative ai gai technologies like c...
# 4  abstract this research delves into the perspec...

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt # Importing the necessary library

data = pd.read_excel('/content/merged_file.xlsx')

data.head()

filtered_data = data[data['published_year'].between(2015, 2024)]

# Count the occurrences of each year and sort by year
year_counts = filtered_data['published_year'].value_counts().sort_index()

# Plotting the data
plt.figure(figsize=(10, 6)) # Now 'plt' is defined and can be used
year_counts.plot(kind='bar')
plt.xlabel('Year of Publication')
plt.ylabel('Number of Papers')
plt.title('Distribution of AI in Education Papers Over the Years (2018-2024)')
plt.show()

# %%
# Word Cloud for Titles

# !pip install wordcloud
from wordcloud import WordCloud

title_text = ' '.join(data['title'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(title_text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Paper Titles')
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# Word Cloud for Abstracts
abstract_text = ' '.join(data['abstract'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(abstract_text)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Abstracts')
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Preprocessing function
def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word for word in tokens if word not in stop_words]
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)




data['processed_abstract'] = data['abstract'].apply(preprocess_text)

# Save preprocessed data
data.to_excel('preprocessed.xlsx', index=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from openai import OpenAI
import pandas as pd
import os

client = OpenAI(
api_key = "LA-70d99a623e53442fa838ea54ba2118eb207c85ecda8b44488c78c32601426258",
base_url = "https://api.llama-api.com"
)

def check_abs(comment):


    response = client.chat.completions.create(
    model="llama3.1-70b",
    messages=[
        {
            "role": "system",
            "content": "You are an experienced paper reviewer, and now you need to screen a batch of papers. Each time you will be given an abstract of a paper, you need to read it carefully, and finally you need to output a number: the number indicates whether this paper is related to 'Generative AI' (0 means irrelevant, 1 means relevant), Your response format should be 'number 1'."
        },
        {
            "role": "user",
            "content": comment
        }
    ],


    )
    return response.choices[0].message.content

columns = ['title', 'published_year', 'url', 'authors','processed_abstract', 'relevant_to_GAI']

def create_or_load_excel(file_path, columns):
    if os.path.exists(file_path):
        df = pd.read_excel(file_path)
    else:
        df = pd.DataFrame(columns=columns)
        df.to_excel(file_path, index=False)
    return df

def append_data_to_excel(file_path, data_list):
    df = create_or_load_excel(file_path, columns)
    new_data_df = pd.DataFrame(data_list)
    df = pd.concat([df, new_data_df], ignore_index=True)
    df.to_excel(file_path, index=False)

def process_excel(input_file, output_file, batch_size=50, start_row=0):
    # Read the input Excel file
    df = pd.read_excel(input_file)

    # Check if 'abstract' column exists
    if 'processed_abstract' not in df.columns:
        raise ValueError("The input Excel file does not contain an 'abstract' column.")

    # Validate start_row
    if start_row < 0 or start_row >= len(df):
        raise ValueError(f"Invalid start_row {start_row}. It should be between 0 and {len(df) - 1}.")

    # Loop through the rows in batches, starting from the specified start_row
    c=1
    for current_row in range(start_row, len(df), batch_size):
        # Slice the next batch
        end_row = min(current_row + batch_size, len(df))
        batch = df.iloc[current_row:end_row].copy()

        # Manually process each row and check relevance of the abstract
        for index, row in batch.iterrows():
            # Get the abstract from the current row
            abstract = row['processed_abstract']

            # Check if the abstract is relevant to GAI
            relevant_to_GAI = check_abs(abstract)

            # Add the result to the batch
            batch.at[index, 'relevant_to_GAI'] = relevant_to_GAI

        batch_list_of_dicts = batch.to_dict(orient='records')
        append_data_to_excel(output_file, batch_list_of_dicts)

        print(f"Batch {c} extracted successfully ")
        c+=1

    print(f"Processing complete. Output saved to {output_file}.")


process_excel('preprocessed.xlsx', 'merged_classified_file.xlsx', batch_size=100, start_row=0)
# Out:
# Batch 1 extracted successfully
# Batch 2 extracted successfully

# %%
import pandas as pd

# Loading two files
file1 = "merged_classified (5).xlsx"
file2 = "merged_classified (6).xlsx"

df1 = pd.read_excel(file1)
df2 = pd.read_excel(file2)

# Combine the DataFrames
merged_df = pd.concat([df1, df2], ignore_index=True)

# Save the merged DataFrame to a new Excel file
merged_df.to_excel("merged_classified_file.xlsx", index=False)

print("Files merged successfully into 'merged_file.xlsx'")
# Out:
# Files merged successfully into 'merged_file.xlsx'

# %%
from openai import OpenAI
import pandas as pd
import os

client = OpenAI(
api_key = "LA-70d99a623e53442fa838ea54ba2118eb207c85ecda8b44488c78c32601426258",
base_url = "https://api.llama-api.com"
)

def check_abs(comment):


    response = client.chat.completions.create(
    model="llama3.1-70b",
    messages=[
        {
            "role": "system",
            "content": "You are an experienced paper reviewer, and now you need to screen a batch of papers. Each time you will be given an abstract of a paper, you need to read it carefully, and finally you need to output a number: the number indicates whether this paper is related to 'Education' (0 means irrelevant, 1 means relevant), Your response format should be 'number 1'."
        },
        {
            "role": "user",
            "content": comment
        }
    ],


    )
    return response.choices[0].message.content

columns = ['title', 'published_year', 'url', 'authors','processed_abstract', 'relevant_to_GAI','relevant_to_EDU']

def create_or_load_excel(file_path, columns):
    if os.path.exists(file_path):
        df = pd.read_excel(file_path)
    else:
        df = pd.DataFrame(columns=columns)
        df.to_excel(file_path, index=False)
    return df

def append_data_to_excel(file_path, data_list):
    df = create_or_load_excel(file_path, columns)
    new_data_df = pd.DataFrame(data_list)
    df = pd.concat([df, new_data_df], ignore_index=True)
    df.to_excel(file_path, index=False)

def process_excel(input_file, output_file, batch_size=50, start_row=0):
    # Read the input Excel file
    df = pd.read_excel(input_file)

    # Check if 'abstract' column exists
    if 'processed_abstract' not in df.columns:
        raise ValueError("The input Excel file does not contain an 'abstract' column.")

    # Validate start_row
    if start_row < 0 or start_row >= len(df):
        raise ValueError(f"Invalid start_row {start_row}. It should be between 0 and {len(df) - 1}.")

    # Loop through the rows in batches, starting from the specified start_row
    c=1
    for current_row in range(start_row, len(df), batch_size):
        # Slice the next batch
        end_row = min(current_row + batch_size, len(df))
        batch = df.iloc[current_row:end_row].copy()  # Copy to avoid modifying the original DataFrame

        # Manually process each row and check relevance of the abstract
        for index, row in batch.iterrows():
            # Get the abstract from the current row
            abstract = row['processed_abstract']

            # Check if the abstract is relevant to EDU
            relevant_to_EDU = check_abs(abstract)

            # Add the result to the batch
            batch.at[index, 'relevant_to_EDU'] = relevant_to_EDU

        batch_list_of_dicts = batch.to_dict(orient='records')
        append_data_to_excel(output_file, batch_list_of_dicts)

        print(f"Batch {c} extracted successfully ")
        c+=1

    print(f"Processing complete. Output saved to {output_file}.")


process_excel('merged_classified_file.xlsx', 'merged_classified.xlsx', batch_size=100, start_row=0)
# Out:
# Batch 1 extracted successfully
# Batch 2 extracted successfully
# Batch 3 extracted successfully
# Batch 4 extracted successfully
# Batch 5 extracted successfully
# Batch 6 extracted successfully
# Batch 7 extracted successfully
# Batch 8 extracted successfully
# Batch 9 extracted successfully
# Batch 10 extracted successfully
# Batch 11 extracted successfully
# Batch 12 extracted successfully
# Batch 13 extracted successfully
# Batch 14 extracted successfully
# Batch 15 extracted successfully
# Batch 16 extracted successfully
# Batch 17 extracted successfully
# Batch 18 extracted successfully
# Batch 19 extracted successfully
# Batch 20 extracted successfully
# Batch 21 extracted successfully
# Batch 22 extracted successfully
# Batch 23 extracted successfully
# Batch 24 extracted successfully
# Batch 25 extracted successfully
# Batch 26 extracted successfully
# Batch 27 extracted successfully
# Batch 28 extracted successfully
# Batch 29 extracted successfully
# Batch 30 extracted successfully
# Batch 31 extracted successfully
# Batch 32 extracted successfully
# Batch 33 extracted successfully
# Batch 34 extracted successfully
# Batch 35 extracted successfully
# Batch 36 extracted successfully
# Batch 37 extracted successfully
# Batch 38 extracted successfully
# Batch 39 extracted successfully
# Batch 40 extracted successfully
# Batch 41 extracted successfully
# Batch 42 extracted successfully
# Batch 43 extracted successfully
# Batch 44 extracted successfully
# Batch 45 extracted successfully
# Batch 46 extracted successfully
# Batch 47 extracted successfully
# Batch 48 extracted successfully
# Batch 49 extracted successfully
# Batch 50 extracted successfully
# Batch 51 extracted successfully
# Batch 52 extracted successfully
# Batch 53 extracted successfully
# Batch 54 extracted successfully
# Batch 55 extracted successfully
# Batch 56 extracted successfully
# Batch 57 extracted successfully
# Batch 58 extracted successfully
# Batch 59 extracted successfully
# Batch 60 extracted successfully
# Batch 61 extracted successfully
# Batch 62 extracted successfully
# Batch 63 extracted successfully
# Batch 64 extracted successfully
# Processing complete. Output saved to merged_classified.xlsx.

# %%
df=pd.read_excel('merged_classified.xlsx')
df.dtypes
# Out:
# title                 object
# published_year         int64
# url                   object
# authors               object
# processed_abstract    object
# relevant_to_GAI       object
# relevant_to_EDU       object
# abstract              object
# dtype: object

# %%
print("Initial dataset shape:", df.shape)

# Clean the 'relevant_to_GAI' and 'relevant_to_EDU' columns
def is_valid_classification(value):
    """
    Checks if the value is a valid classification (0 or 1).
    """
    try:
        int_value = int(value)
        return int_value in [0, 1]
    except (ValueError, TypeError):
        return False

# Apply the validation function to both columns and filter the dataframe
df_cleaned = df[df['relevant_to_GAI'].apply(is_valid_classification) & df['relevant_to_EDU'].apply(is_valid_classification)]

# Convert the columns to integer type for consistency
df_cleaned['relevant_to_GAI'] = df_cleaned['relevant_to_GAI'].astype(int)
df_cleaned['relevant_to_EDU'] = df_cleaned['relevant_to_EDU'].astype(int)

# Display final dataset information
print("Cleaned dataset shape:", df_cleaned.shape)

# Save the cleaned dataset
cleaned_file_path = "cleaned_dataset.xlsx"
df_cleaned.to_excel(cleaned_file_path, index=False)
print(f"Cleaned dataset saved to {cleaned_file_path}")
# Out:
# Initial dataset shape: (6400, 8)
# Cleaned dataset shape: (5761, 8)
# <ipython-input-76-19b6a46192df>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['relevant_to_GAI'] = df_cleaned['relevant_to_GAI'].astype(int)
# <ipython-input-76-19b6a46192df>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['relevant_to_EDU'] = df_cleaned['relevant_to_EDU'].astype(int)
# Cleaned dataset saved to cleaned_dataset.xlsx

# %%
import pandas as pd

df_cleaned=pd.read_excel('cleaned_dataset.xlsx')


# Drop rows where both 'relevant_to_GAI' and 'relevant_to_EDU' are 0
df_cleaned = df_cleaned[(df_cleaned['relevant_to_GAI'] != 0) | (df_cleaned['relevant_to_EDU'] != 0)]

# Create a new column 'both_relevant' that is 1 if both 'relevant_to_GAI' and 'relevant_to_EDU' are 1, otherwise 0
df_cleaned['both_relevant'] = ((df_cleaned['relevant_to_GAI'] == 1) & (df_cleaned['relevant_to_EDU'] == 1)).astype(int)

# Display some of the updated DataFrame to verify the changes
print(df_cleaned.head())

# Optionally, display the shape of the DataFrame to confirm dimensions
print("Updated dataset shape:", df_cleaned.shape)

# Save the updated dataset, overwriting the original file
file_path = "cleaned_dataset.xlsx"  # Change this to your original file path if different
df_cleaned.to_excel(file_path, index=False)
print(f"Dataset updates saved back to {file_path}")
# Out:
#                                                title  published_year  \
# 0  application research of generative artificial ...            2024
# 1  application of generative artificial intellige...            2024
# 2              generative ai in higher art education            2024
# 3  unveiling generative ai in higher education in...            2024
# 4  workshop educational innovation through genera...            2024
#
#                                                  url  \
# 0  https://ieeexplore-ieee-org.libproxy.library.u...
# 1  https://ieeexplore-ieee-org.libproxy.library.u...
# 2  https://ieeexplore-ieee-org.libproxy.library.u...
# 3  https://ieeexplore-ieee-org.libproxy.library.u...
# 4  https://ieeexplore-ieee-org.libproxy.library.u...
#
#                                              authors  \
# 0  ['Jing Ning', 'Yi Gao', 'Mingxin Luo', '', '',...
# 1  ['Ying Li', 'Wei Ji', 'Jiaqi Liu', 'Wenqing Li...
# 2   ['Xi Chen', 'Yuebin Liao', 'Wei Yu', '', '', '']
# 3  ['Nicia Guillén-Yparrea', 'Felipe Hernández-Ro...
# 4  ['Miguel Morales-Chan', 'Hector R. Amado-Salva...
#
#                                   processed_abstract  relevant_to_GAI  \
# 0  abstract education mode art design education c...                1
# 1  abstract today rapidly evolving education fiel...                1
# 2  abstract research delf perspective chinese uni...                1
# 3  abstract widespread use generative artificial ...                1
# 4  abstract integration artificial intelligence a...                1
#
#    relevant_to_EDU                                           abstract  \
# 0                1  abstract the education mode of art design educ...
# 1                1  abstract in todays rapidly evolving education ...
# 2                1  abstract this research delves into the perspec...
# 3                1  abstract the widespread use of generative arti...
# 4                1  abstract the integration of artificial intelli...
#
#    both_relevant
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# Updated dataset shape: (4705, 9)
# Dataset updates saved back to cleaned_dataset.xlsx

# %%
df_cleaned=pd.read_excel('cleaned_dataset.xlsx')

import matplotlib.pyplot as plt

# Calculate counts for each category
count_relevant_GAI = (df_cleaned['relevant_to_GAI'] == 1).sum()
count_relevant_EDU = (df_cleaned['relevant_to_EDU'] == 1).sum()
count_both = (df_cleaned['both_relevant'] == 1).sum()
count_anyone = (df_cleaned['both_relevant'] == 0).sum()

# Categories
categories = ['Relevant to GAI', 'Relevant to EDU', 'Relevant to Both', 'Relevant to Neither']
counts = [count_relevant_GAI, count_relevant_EDU, count_both, count_anyone]

# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(categories, counts, color=['blue', 'green', 'red', 'gray'])
plt.title('Count of Papers by Relevance')
plt.xlabel('Category')
plt.ylabel('Number of Papers')
plt.show()

# %%
# Creating the pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=140, colors=['blue', 'green', 'red', 'purple'])
plt.title('Proportion of Papers by Relevance')
plt.show()

# %%
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (3.2.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.6)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.46.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.5.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (11.0.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.8.30)
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 6.5 MB/s eta 0:00:00
# Downloading hdbscan-0.8.40-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.6 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 6.4 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.16.4 hdbscan-0.8.40 pynndescent-0.5.13 umap-learn-0.5.7

# %%
from sklearn.feature_extraction.text import CountVectorizer
from bertopic import BERTopic

# Create a CountVectorizer for topic modeling
data=pd.read_excel('cleaned_dataset.xlsx')
vectorizer = CountVectorizer()
vectorized_data = vectorizer.fit_transform(data['processed_abstract'])

# %%
# Apply BERTopic
topic_model = BERTopic()
topics, probs = topic_model.fit_transform(data['processed_abstract'])
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Prepare timestamps (published years)
timestamps = data['published_year']  # Ensure 'published_date' is in datetime format

# %%
# Calculate topics over time
topics_over_time = topic_model.topics_over_time(data['processed_abstract'], timestamps)

# %%
# Visualize topics over time
fig = topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=20)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4f18397d-7112-48ad-b40e-8f3443178ca8" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f18397d-7112-48ad-b40e-8f3443178ca8")) {                    Plotly.newPlot(                        "4f18397d-7112-48ad-b40e-8f3443178ca8",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: useful, perfect, cost, heuristic, opt","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ai, ammanath, definition, respondent, peace","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ai, symbiotic, government, ss, impact","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: enterprise, financial, business, police, ai","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: financial, ai, intelligence, artificial, policy","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ai, intelligence, artificial, government, saudi","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ai, financial, business, intelligence, artificial","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: ai, financial, intelligence, business, technology"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_ai_financial_intelligence_artificial","x":[2016,2018,2019,2020,2021,2022,2023,2024],"y":[1,4,7,9,12,18,47,45],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: driver, driving, crash, mobile, novice","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: traffic, pedestrian, edge, surveillance, masm","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: bus, rider, motorcycle, connectivity, pbsw","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: edge, traffic, network, computing, mec","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: road, edge, network, vehicle, iot","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: edge, traffic, network, vehicle, computing","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: edge, network, vehicle, aigc, traffic"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_edge_network_traffic_vehicle","x":[2018,2019,2020,2021,2022,2023,2024],"y":[4,4,2,12,13,29,52],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: af, fibrillation, atrial, healthcare, sr","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: healthcare, medical, ultrasound, diagnostic, talk","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: covid, healthcare, patient, elderly, health","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: healthcare, medical, disease, covid, diagnosis","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: disease, patient, healthcare, diagnosis, medical","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: healthcare, patient, medical, diabetes, treatment","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: healthcare, patient, medical, health, disease"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_healthcare_patient_medical_disease","x":[2018,2019,2020,2021,2022,2023,2024],"y":[3,2,7,6,14,36,44],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: academic, performance, grade, predict, mining","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: performance, classifier, mining, mi, specificity","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: brazil, gois, federal, schedule, analysed","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: exam, performance, student, mir, test","\u003cb\u003eTopic 3\ ...
